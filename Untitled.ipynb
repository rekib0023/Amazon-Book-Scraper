# %%
import pandas as pd

# %%
df = pd.read_csv("engineering_books.csv")

# %%
df
# Out:
#                                                 title  \
# 0             Hand book of Hydro Electric Engineering
# 1   Civil Engineeering Practice Book For SSC JE Ma...
# 2   Civil Engineering Through Objective Type Quest...
# 3   Conventional & Objective Type Questions & Answ...
# 4   Mechanical Engineering: Conventional and Objec...
# 5   Civil Engineering: Conventional and Objective ...
# 6   Negotiating Your Career in Structural Engineer...
# 7   UPPSC State PSC PSU ESE Assistant Civil Engine...
# 8   Objective Electrical Technology (2018-19 Session)
# 9               Basics of civil engineering hand book
# 10  Applied Statistics and Probability for Enginee...
# 11      Engineering Mechanics: Problems and Solutions
# 12  3500 MCQs : Electrical Engineering- Practice B...
# 13               Fundamentals of Software Engineering
# 14  GATE - 2021 - Civil Engineering (34 Years Solu...
# 15  ESE 2021 - Civil Engineering ESE Topicwise Obj...
# ...
